# %%
pip install gmaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gmaps
from datetime import datetime

secretapi_key = {
    "API_KEY": "AIzaSyBpjEKrlbfkGbVUU8LgiaBFVPHvCADIVgY"
}

gmaps.configure(api_key=secretapi_key["API_KEY"])
now = datetime.now()
fig = gmaps.figure()
origin = (47.224126, 8.980706)
destination = (47.224957, 8.817066)
layer = gmaps.directions.Directions(origin, destination, mode="transit", departure_time=now)
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
